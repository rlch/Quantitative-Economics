# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(theta, radii, width=width, bottom = 0.0)

for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10))
    bar.set_alpha(0.5)

# %% [markdown]
# If $\{A_n\}$ is pairwise disjoint, then
#
# $$ \mu(\cup_n A_n) = \sum_m \mu(A_n) $$

# %%
# !pip install --upgrade quantecon
# Out:
# Collecting quantecon
#   Downloading https://files.pythonhosted.org/packages/a7/2a/a3b740e670011a063a445dfcb2c30801238c4e70a75f89d8eb7d846bb125/quantecon-0.4.5.tar.gz (138kB)
#      |████████████████████████████████| 143kB 2.4MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numba>=0.38 in /Users/development/anaconda3/lib/python3.7/site-packages (from quantecon) (0.44.1)
# Requirement already satisfied, skipping upgrade: numpy in /Users/development/anaconda3/lib/python3.7/site-packages (from quantecon) (1.16.4)
# Requirement already satisfied, skipping upgrade: requests in /Users/development/anaconda3/lib/python3.7/site-packages (from quantecon) (2.22.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.0 in /Users/development/anaconda3/lib/python3.7/site-packages (from quantecon) (1.3.0)
# Requirement already satisfied, skipping upgrade: sympy in /Users/development/anaconda3/lib/python3.7/site-packages (from quantecon) (1.4)
# Requirement already satisfied, skipping upgrade: llvmlite>=0.29.0 in /Users/development/anaconda3/lib/python3.7/site-packages (from numba>=0.38->quantecon) (0.29.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Users/development/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/development/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (2019.6.16)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/development/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (1.24.2)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/development/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (3.0.4)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /Users/development/anaconda3/lib/python3.7/site-packages (from sympy->quantecon) (1.1.0)
# Building wheels for collected packages: quantecon
#   Building wheel for quantecon (setup.py) ... done
#   Stored in directory: /Users/development/Library/Caches/pip/wheels/cf/80/42/ea1feb22ce8fd1f2f230bcce9c104c490fa376a01c8e9faf79
# Successfully built quantecon
# Installing collected packages: quantecon
# Successfully installed quantecon-0.4.5

# %%
# !pip install interpolation
# Out:
# Collecting interpolation
#   Downloading https://files.pythonhosted.org/packages/52/35/d760068c72b479bbc319c3f46daecbbb975df3077269ad971aa495fa4c17/interpolation-2.1.2-py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 2.0MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/development/anaconda3/lib/python3.7/site-packages (from interpolation) (1.16.4)
# Collecting tempita (from interpolation)
#   Downloading https://files.pythonhosted.org/packages/56/c8/8ed6eee83dbddf7b0fc64dd5d4454bc05e6ccaafff47991f73f2894d9ff4/Tempita-0.5.2.tar.gz
# Requirement already satisfied: scipy in /Users/development/anaconda3/lib/python3.7/site-packages (from interpolation) (1.3.0)
# Requirement already satisfied: numba in /Users/development/anaconda3/lib/python3.7/site-packages (from interpolation) (0.44.1)
# Requirement already satisfied: llvmlite>=0.29.0 in /Users/development/anaconda3/lib/python3.7/site-packages (from numba->interpolation) (0.29.0)
# Building wheels for collected packages: tempita
#   Building wheel for tempita (setup.py) ... done
#   Stored in directory: /Users/development/Library/Caches/pip/wheels/1e/db/04/d827f417f162a149fbdfdd1d015c7769b393124aa98eb29642
# Successfully built tempita
# Installing collected packages: tempita, interpolation
# Successfully installed interpolation-2.1.2 tempita-0.5.2
